# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler

# %%
from sklearn import cluster, datasets
n_samples = 1500
X, y = datasets.make_circles(
    n_samples=n_samples, factor=0.5, noise=0.05, random_state=170
)

# %%
# Plotting the dataset
plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1])
plt.title('Noisy Circles')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=2, n_init='auto')
km.fit(X)
km.labels_
# Out:
# array([0, 1, 1, ..., 1, 0, 0], shape=(1500,), dtype=int32)

# %%
plt.scatter(X[:, 0], X[:, 1], c=km.labels_, edgecolor='k')

# %% [markdown]
# #### Using Hierarchical Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

hc = AgglomerativeClustering(n_clusters=2, linkage="single")
hc.fit(X)
hc.labels_
# Out:
# array([1, 1, 0, ..., 1, 0, 1], shape=(1500,))

# %%
plt.scatter(X[:, 0], X[:, 1], c=hc.labels_, edgecolor='k')

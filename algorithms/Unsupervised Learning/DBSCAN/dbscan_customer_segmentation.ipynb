# %% [markdown]
# <h3 align='center'>DBSCAN Clustering</h3>

# %% [markdown]
# Problem Statement: Use DBSCAN clustering for customer segmentation. We will cluster people based on their income and age.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_excel("D:/Coding/Machine Learning/dataset/income.xlsx", names=["name","age","income"])
df
# Out:
#       name  age  income
# 0      Rob   29      45
# 1   Andrea   50      80
# 2    Mohan   35      52
# 3  Michael   32      41
# 4     Kory   36      87
# 5    David   48      68
# 6   Ismail   31      80
# 7   Sheela   55      60

# %%
sns.scatterplot(df, x='age', y='income', s=100)
plt.show()

# %% [markdown]
# ### Form clusters using DBSCAN

# %%
from sklearn.cluster import DBSCAN

ds = DBSCAN(eps=10, min_samples=2)
ds.fit(df[['age', 'income']])
ds.labels_
# Out:
# array([ 0, -1,  0,  0,  1, -1,  1, -1])

# %%
df["cluster"] = ds.labels_
df
# Out:
#       name  age  income  cluster
# 0      Rob   29      45        0
# 1   Andrea   50      80       -1
# 2    Mohan   35      52        0
# 3  Michael   32      41        0
# 4     Kory   36      87        1
# 5    David   48      68       -1
# 6   Ismail   31      80        1
# 7   Sheela   55      60       -1

# %%
sns.scatterplot(df, x='age', y='income',  palette='viridis', s=100, hue="cluster")
plt.show()
